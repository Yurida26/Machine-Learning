# %% [markdown]
# # Import Library Dasar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1wgTtW_FbrTFwqDA5ndhK0jQ1Wmz9WDJ5')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Pemeriksaan Missing Values (Data Kososng)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Data Cleaning (Menghapus kolom yang tidak digunakan)

# %%
# drop kolom
df = df.drop(columns=['Cabin', 'Name', 'Ticket'], axis=1)

# %% [markdown]
# # Visualisasi Distribusi dan outlier pada kolom age

# %%
df.boxplot(column='Age')
# Out:
# <Axes: >

# %% [markdown]
# # Mengisi nilai kosong pada kolom age dengan median

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# /tmp/ipython-input-1933487976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %% [markdown]
# # Mengisi nilai kosong pada kolom embarked dengan modus

# %%
# replacing the missing value in "Embarked" column with mode value
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1047536694.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %% [markdown]
# # Verifikasi ulang missing values

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Encoding data kategorikal

# %%
replacements = {
    'Sex':{'male': 0, 'female': 1},
    'Embarked': {'S': 0, 'C': 1, 'Q': 2}
}
df.replace(replacements, inplace=True)
# Out:
# /tmp/ipython-input-2365114707.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(replacements, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         0
# 1            2         1       1    1  38.0      1      0  71.2833         1
# 2            3         1       3    1  26.0      0      0   7.9250         0
# 3            4         1       1    1  35.0      1      0  53.1000         0
# 4            5         0       3    0  35.0      0      0   8.0500         0

# %% [markdown]
# # Split data dan transformasi(Scaling)

# %% [markdown]
# # Split Data variabel X dan Y

# %%
X = df.drop('Survived', axis=1)
y = df['Survived']

# %% [markdown]
# # Transform data

# %%
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# # Modelling

# %%
X_train.shape
# Out:
# (712, 8)

# %%
X_train.shape[1]
# Out:
# 8

# %% [markdown]
# # Pembuatan model neural network (Arsitektur ANN)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

model = Sequential()

# Hidden layer 1
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))

# Dropout untuk mengurangi overfitting
model.add(Dropout(0.3))

# Hidden layer 2
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.3))

# Output layer (binary classification)
model.add(Dense(1, activation='sigmoid' ))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Kompilasi model dan ringkasan arsitektur (model summary)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 833 (3.25 KB)
#  Trainable params: 833 (3.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Early stopping (Pencegahan overfitting selama training)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop =EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %% [markdown]
# #  Training Model Neural Network

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.4592 - loss: 0.7104 - val_accuracy: 0.6853 - val_loss: 0.6594
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6171 - loss: 0.6380 - val_accuracy: 0.7203 - val_loss: 0.6382
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6596 - loss: 0.6547 - val_accuracy: 0.7203 - val_loss: 0.6181
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7233 - loss: 0.6310 - val_accuracy: 0.7133 - val_loss: 0.5999
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6881 - loss: 0.6103 - val_accuracy: 0.7413 - val_loss: 0.5819
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7370 - loss: 0.5897 - val_accuracy: 0.7622 - val_loss: 0.5606
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7590 - loss: 0.5501 - val_accuracy: 0.7762 - val_loss: 0.5370
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7408 - loss: 0.5511 - val_accuracy: 0.7692 - val_loss: 0.5169
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7808 - loss: 0.5159 - val_accuracy: 0.7692 - val_loss: 0.4993
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7631 - loss: 0.5436 - val_accuracy: 0.7832 - val_loss: 0.4836
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7492 - loss: 0.5394 - val_accuracy: 0.7762 - val_loss: 0.4690
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7760 - loss: 0.4908 - val_accuracy: 0.7902 - val_loss: 0.4595
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8006 - loss: 0.4857 - val_accuracy: 0.7902 - val_loss: 0.4522
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7591 - loss: 0.5448 - val_accuracy: 0.7972 - val_loss: 0.4455
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7786 - loss: 0.4651 - val_accuracy: 0.7972 - val_loss: 0.4390
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7652 - loss: 0.4994 - val_accuracy: 0.8042 - val_loss: 0.4354
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7879 - loss: 0.4573 - val_accuracy: 0.7972 - val_loss: 0.4321
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7743 - loss: 0.4616 - val_accuracy: 0.8042 - val_loss: 0.4297
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7777 - loss: 0.4729 - val_accuracy: 0.8112 - val_loss: 0.4269
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8220 - loss: 0.4450 - val_accuracy: 0.8112 - val_loss: 0.4239
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8279 - loss: 0.4451 - val_accuracy: 0.8112 - val_loss: 0.4193
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8279 - loss: 0.4163 - val_accuracy: 0.8322 - val_loss: 0.4161
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8083 - loss: 0.4685 - val_accuracy: 0.8322 - val_loss: 0.4158
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8191 - loss: 0.4411 - val_accuracy: 0.8322 - val_loss: 0.4114
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8001 - loss: 0.4475 - val_accuracy: 0.8322 - val_loss: 0.4107
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7944 - loss: 0.4420 - val_accuracy: 0.8392 - val_loss: 0.4102
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7969 - loss: 0.4634 - val_accuracy: 0.8322 - val_loss: 0.4111
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7912 - loss: 0.4514 - val_accuracy: 0.8252 - val_loss: 0.4087
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7942 - loss: 0.4491 - val_accuracy: 0.8252 - val_loss: 0.4040
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7919 - loss: 0.4470 - val_accuracy: 0.8392 - val_loss: 0.4057
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7914 - loss: 0.4617 - val_accuracy: 0.8322 - val_loss: 0.4072
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8224 - loss: 0.4058 - val_accuracy: 0.8392 - val_loss: 0.4031
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8107 - loss: 0.4672 - val_accuracy: 0.8392 - val_loss: 0.4035
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8225 - loss: 0.4268 - val_accuracy: 0.8462 - val_loss: 0.3993
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7745 - loss: 0.4658 - val_accuracy: 0.8462 - val_loss: 0.4026
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8286 - loss: 0.4213 - val_accuracy: 0.8462 - val_loss: 0.4004
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8324 - loss: 0.4027 - val_accuracy: 0.8462 - val_loss: 0.4009
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7993 - loss: 0.4435 - val_accuracy: 0.8531 - val_loss: 0.4000
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8242 - loss: 0.4283 - val_accuracy: 0.8392 - val_loss: 0.4027

# %% [markdown]
# # Evaluasi Model (Testing Data)

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Loss      :", loss)
print("Test Accuracy  :", accuracy)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8243 - loss: 0.3982
# Test Loss      : 0.4081276059150696
# Test Accuracy  : 0.8156424760818481

# %% [markdown]
# # Visualisasi Hasil Pelatihan (Accuracy dan Loss)

# %%
plt.figure(figsize=(12,4))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy' )
plt.plot(history.history['val_accuracy'], label='Validation Accuracy' )
plt.title('Model Accuracy' )
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss' )
plt.title('Model Loss' )
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
